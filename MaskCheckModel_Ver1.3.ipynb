# %% [markdown]
# # 1. Package Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os

import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import *
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

print("Tensorflow Version : ", tf.__version__)
print("Keras Version : ", keras.__version__)
# Out:
# Using TensorFlow backend.
# Tensorflow Version :  1.15.0
# Keras Version :  2.2.4-tf

# %% [markdown]
# # 2. GPU Setting

# %%
# from tensorflow.python.client import device_lib
# print(device_lib.list_local_devices())

# [참고] https://datamasters.co.kr/33
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %% [markdown]
# # 3. Data Setting

# %%
dir_data = "C:/Users/User/Desktop/Project/Full_Ver3.0/" # 데이터 경로
filenames = os.listdir(dir_data)
filenames
# Out:
# ['Background (1).png',
#  'Background (10).png',
#  'Background (11).png',
#  'Background (12).png',
#  'Background (13).png',
#  'Background (14).png',
#  'Background (15).png',
#  'Background (16).png',
#  'Background (17).png',
#  'Background (18).png',
#  'Background (19).png',
#  'Background (2).png',
#  'Background (20).png',
#  'Background (21).png',
#  'Background (22).png',
#  'Background (23).png',
#  'Background (24).png',
#  'Background (25).png',
#  'Background (26).png',
#  'Background (27).png',
#  'Background (28).png',
#  'Background (29).png',
#  'Background (3).png',
#  'Background (30).png',
#  'Background (31).png',
#  'Background (32).png',
#  'Background (33).png',
#  'Background (34).png',
#  'Background (35).png',
#  'Background (4).png',
#  'Background (5).png',
#  'Background (6).png',
#  'Background (7).png',
#  'Background (8).png',
#  'Background (9).png',
#  'Capture_off (1).png',
#  'Capture_off (10).png',
#  'Capture_off (100).png',
#  'Capture_off (101).png',
#  'Capture_off (102).png',
#  'Capture_off (103).png',
#  'Capture_off (104).png',
#  'Capture_off (105).png',
#  'Capture_off (106).png',
#  'Capture_off (107).png',
#  'Capture_off (108).png',
#  'Capture_off (109).png',
#  'Capture_off (11).png',
#  'Capture_off (110).png',
#  'Capture_off (111).png',
#  'Capture_off (112).png',
#  'Capture_off (113).png',
#  'Capture_off (114).png',
#  'Capture_off (115).png',
#  'Capture_off (116).png',
#  'Capture_off (117).png',
#  'Capture_off (118).png',
#  'Capture_off (119).png',
#  'Capture_off (12).png',
#  'Capture_off (120).png',
#  'Capture_off (121).png',
#  'Capture_off (122).png',
#  'Capture_off (123).png',
#  'Capture_off (124).png',
#  'Capture_off (125).png',
#  'Capture_off (126).png',
#  'Capture_off (127).png',
#  'Capture_off (128).png',
#  'Capture_off (129).png',
#  'Capture_off (13).png',
#  'Capture_off (130).png',
#  'Capture_off (131).png',
#  'Capture_off (132).png',
#  'Capture_off (133).png',
#  'Capture_off (134).png',
#  'Capture_off (135).png',
#  'Capture_off (136).png',
#  'Capture_off (137).png',
#  'Capture_off (138).png',
#  'Capture_off (139).png',
#  'Capture_off (14).png',
#  'Capture_off (140).png',
#  'Capture_off (141).png',
#  'Capture_off (142).png',
#  'Capture_off (143).png',
#  'Capture_off (144).png',
#  'Capture_off (145).png',
#  'Capture_off (146).png',
#  'Capture_off (147).png',
#  'Capture_off (148).png',
#  'Capture_off (149).png',
#  'Capture_off (15).png',
#  'Capture_off (150).png',
#  'Capture_off (151).png',
#  'Capture_off (152).png',
#  'Capture_off (153).png',
#  'Capture_off (154).png',
#  'Capture_off (155).png',
#  'Capture_off (156).png',
#  'Capture_off (157).png',
#  'Capture_off (158).png',
#  'Capture_off (159).png',
#  'Capture_off (16).png',
#  'Capture_off (160).png',
#  'Capture_off (161).png',
#  'Capture_off (162).png',
#  'Capture_off (163).png',
#  'Capture_off (164).png',
#  'Capture_off (165).png',
#  'Capture_off (166).png',
#  'Capture_off (167).png',
#  'Capture_off (168).png',
#  'Capture_off (169).png',
#  'Capture_off (17).png',
#  'Capture_off (170).png',
#  'Capture_off (171).png',
#  'Capture_off (172).png',
#  'Capture_off (173).png',
#  'Capture_off (174).png',
#  'Capture_off (175).png',
#  'Capture_off (176).png',
#  'Capture_off (177).png',
#  'Capture_off (18).png',
#  'Capture_off (19).png',
#  'Capture_off (2).png',
#  'Capture_off (20).png',
#  'Capture_off (21).png',
#  'Capture_off (22).png',
#  'Capture_off (23).png',
#  'Capture_off (24).png',
#  'Capture_off (25).png',
#  'Capture_off (26).png',
#  'Capture_off (27).png',
#  'Capture_off (28).png',
#  'Capture_off (29).png',
#  'Capture_off (3).png',
#  'Capture_off (30).png',
#  'Capture_off (31).png',
#  'Capture_off (32).png',
#  'Capture_off (33).png',
#  'Capture_off (34).png',
#  'Capture_off (35).png',
#  'Capture_off (36).png',
#  'Capture_off (37).png',
#  'Capture_off (38).png',
#  'Capture_off (39).png',
#  'Capture_off (4).png',
#  'Capture_off (40).png',
#  'Capture_off (41).png',
#  'Capture_off (42).png',
#  'Capture_off (43).png',
#  'Capture_off (44).png',
#  'Capture_off (45).png',
#  'Capture_off (46).png',
#  'Capture_off (47).png',
#  'Capture_off (48).png',
#  'Capture_off (49).png',
#  'Capture_off (5).png',
#  'Capture_off (50).png',
#  'Capture_off (51).png',
#  'Capture_off (52).png',
#  'Capture_off (53).png',
#  'Capture_off (54).png',
#  'Capture_off (55).png',
#  'Capture_off (56).png',
#  'Capture_off (57).png',
#  'Capture_off (58).png',
#  'Capture_off (59).png',
#  'Capture_off (6).png',
#  'Capture_off (60).png',
#  'Capture_off (61).png',
#  'Capture_off (62).png',
#  'Capture_off (63).png',
#  'Capture_off (64).png',
#  'Capture_off (65).png',
#  'Capture_off (66).png',
#  'Capture_off (67).png',
#  'Capture_off (68).png',
#  'Capture_off (69).png',
#  'Capture_off (7).png',
#  'Capture_off (70).png',
#  'Capture_off (71).png',
#  'Capture_off (72).png',
#  'Capture_off (73).png',
#  'Capture_off (74).png',
#  'Capture_off (75).png',
#  'Capture_off (76).png',
#  'Capture_off (77).png',
#  'Capture_off (78).png',
#  'Capture_off (79).png',
#  'Capture_off (8).png',
#  'Capture_off (80).png',
#  'Capture_off (81).png',
#  'Capture_off (82).png',
#  'Capture_off (83).png',
#  'Capture_off (84).png',
#  'Capture_off (85).png',
#  'Capture_off (86).png',
#  'Capture_off (87).png',
#  'Capture_off (88).png',
#  'Capture_off (89).png',
#  'Capture_off (9).png',
#  'Capture_off (90).png',
#  'Capture_off (91).png',
#  'Capture_off (92).png',
#  'Capture_off (93).png',
#  'Capture_off (94).png',
#  'Capture_off (95).png',
#  'Capture_off (96).png',
#  'Capture_off (97).png',
#  'Capture_off (98).png',
#  'Capture_off (99).png',
#  'Capture_on (1).png',
#  'Capture_on (10).png',
#  'Capture_on (100).png',
#  'Capture_on (101).png',
#  'Capture_on (102).png',
#  'Capture_on (103).png',
#  'Capture_on (104).png',
#  'Capture_on (11).png',
#  'Capture_on (12).png',
#  'Capture_on (13).png',
#  'Capture_on (14).png',
#  'Capture_on (15).png',
#  'Capture_on (16).png',
#  'Capture_on (17).png',
#  'Capture_on (18).png',
#  'Capture_on (19).png',
#  'Capture_on (2).png',
#  'Capture_on (20).png',
#  'Capture_on (21).png',
#  'Capture_on (22).png',
#  'Capture_on (23).png',
#  'Capture_on (24).png',
#  'Capture_on (25).png',
#  'Capture_on (26).png',
#  'Capture_on (27).png',
#  'Capture_on (28).png',
#  'Capture_on (29).png',
#  'Capture_on (3).png',
#  'Capture_on (30).png',
#  'Capture_on (31).png',
#  'Capture_on (32).png',
#  'Capture_on (33).png',
#  'Capture_on (34).png',
#  'Capture_on (35).png',
#  'Capture_on (36).png',
#  'Capture_on (37).png',
#  'Capture_on (38).png',
#  'Capture_on (39).png',
#  'Capture_on (4).png',
#  'Capture_on (40).png',
#  'Capture_on (41).png',
#  'Capture_on (42).png',
#  'Capture_on (43).png',
#  'Capture_on (44).png',
#  'Capture_on (45).png',
#  'Capture_on (46).png',
#  'Capture_on (47).png',
#  'Capture_on (48).png',
#  'Capture_on (49).png',
#  'Capture_on (5).png',
#  'Capture_on (50).png',
#  'Capture_on (51).png',
#  'Capture_on (52).png',
#  'Capture_on (53).png',
#  'Capture_on (54).png',
#  'Capture_on (55).png',
#  'Capture_on (56).png',
#  'Capture_on (57).png',
#  'Capture_on (58).png',
#  'Capture_on (59).png',
#  'Capture_on (6).png',
#  'Capture_on (60).png',
#  'Capture_on (61).png',
#  'Capture_on (62).png',
#  'Capture_on (63).png',
#  'Capture_on (64).png',
#  'Capture_on (65).png',
#  'Capture_on (66).png',
#  'Capture_on (67).png',
#  'Capture_on (68).png',
#  'Capture_on (69).png',
#  'Capture_on (7).png',
#  'Capture_on (70).png',
#  'Capture_on (71).png',
#  'Capture_on (72).png',
#  'Capture_on (73).png',
#  'Capture_on (74).png',
#  'Capture_on (75).png',
#  'Capture_on (76).png',
#  'Capture_on (77).png',
#  'Capture_on (78).png',
#  'Capture_on (79).png',
#  'Capture_on (8).png',
#  'Capture_on (80).png',
#  'Capture_on (81).png',
#  'Capture_on (82).png',
#  'Capture_on (83).png',
#  'Capture_on (84).png',
#  'Capture_on (85).png',
#  'Capture_on (86).png',
#  'Capture_on (87).png',
#  'Capture_on (88).png',
#  'Capture_on (89).png',
#  'Capture_on (9).png',
#  'Capture_on (90).png',
#  'Capture_on (91).png',
#  'Capture_on (92).png',
#  'Capture_on (93).png',
#  'Capture_on (94).png',
#  'Capture_on (95).png',
#  'Capture_on (96).png',
#  'Capture_on (97).png',
#  'Capture_on (98).png',
#  'Capture_on (99).png',
#  'Multi_off (1).png',
#  'Multi_off (10).png',
#  'Multi_off (100).png',
#  'Multi_off (101).png',
#  'Multi_off (102).png',
#  'Multi_off (103).png',
#  'Multi_off (104).png',
#  'Multi_off (105).png',
#  'Multi_off (106).png',
#  'Multi_off (107).png',
#  'Multi_off (108).png',
#  'Multi_off (109).png',
#  'Multi_off (11).png',
#  'Multi_off (110).png',
#  'Multi_off (111).png',
#  'Multi_off (112).png',
#  'Multi_off (113).png',
#  'Multi_off (114).png',
#  'Multi_off (115).png',
#  'Multi_off (116).png',
#  'Multi_off (117).png',
#  'Multi_off (118).png',
#  'Multi_off (119).png',
#  'Multi_off (12).png',
#  'Multi_off (120).png',
#  'Multi_off (121).png',
#  'Multi_off (122).png',
#  'Multi_off (123).png',
#  'Multi_off (124).png',
#  'Multi_off (125).png',
#  'Multi_off (126).png',
#  'Multi_off (127).png',
#  'Multi_off (128).png',
#  'Multi_off (129).png',
#  'Multi_off (13).png',
#  'Multi_off (130).png',
#  'Multi_off (131).png',
#  'Multi_off (132).png',
#  'Multi_off (133).png',
#  'Multi_off (134).png',
#  'Multi_off (135).png',
#  'Multi_off (136).png',
#  'Multi_off (137).png',
#  'Multi_off (138).png',
#  'Multi_off (139).png',
#  'Multi_off (14).png',
#  'Multi_off (140).png',
#  'Multi_off (141).png',
#  'Multi_off (142).png',
#  'Multi_off (143).png',
#  'Multi_off (144).png',
#  'Multi_off (145).png',
#  'Multi_off (146).png',
#  'Multi_off (147).png',
#  'Multi_off (148).png',
#  'Multi_off (149).png',
#  'Multi_off (15).png',
#  'Multi_off (150).png',
#  'Multi_off (151).png',
#  'Multi_off (152).png',
#  'Multi_off (153).png',
#  'Multi_off (154).png',
#  'Multi_off (155).png',
#  'Multi_off (156).png',
#  'Multi_off (157).png',
#  'Multi_off (158).png',
#  'Multi_off (159).png',
#  'Multi_off (16).png',
#  'Multi_off (160).png',
#  'Multi_off (161).png',
#  'Multi_off (162).png',
#  'Multi_off (163).png',
#  'Multi_off (164).png',
#  'Multi_off (165).png',
#  'Multi_off (166).png',
#  'Multi_off (167).png',
#  'Multi_off (168).png',
#  'Multi_off (169).png',
#  'Multi_off (17).png',
#  'Multi_off (170).png',
#  'Multi_off (171).png',
#  'Multi_off (172).png',
#  'Multi_off (173).png',
#  'Multi_off (174).png',
#  'Multi_off (175).png',
#  'Multi_off (176).png',
#  'Multi_off (177).png',
#  'Multi_off (178).png',
#  'Multi_off (179).png',
#  'Multi_off (18).png',
#  'Multi_off (180).png',
#  'Multi_off (181).png',
#  'Multi_off (182).png',
#  'Multi_off (183).png',
#  'Multi_off (184).png',
#  'Multi_off (185).png',
#  'Multi_off (186).png',
#  'Multi_off (187).png',
#  'Multi_off (188).png',
#  'Multi_off (189).png',
#  'Multi_off (19).png',
#  'Multi_off (190).png',
#  'Multi_off (191).png',
#  'Multi_off (192).png',
#  'Multi_off (193).png',
#  'Multi_off (194).png',
#  'Multi_off (195).png',
#  'Multi_off (2).png',
#  'Multi_off (20).png',
#  'Multi_off (21).png',
#  'Multi_off (22).png',
#  'Multi_off (23).png',
#  'Multi_off (24).png',
#  'Multi_off (25).png',
#  'Multi_off (26).png',
#  'Multi_off (27).png',
#  'Multi_off (28).png',
#  'Multi_off (29).png',
#  'Multi_off (3).png',
#  'Multi_off (30).png',
#  'Multi_off (31).png',
#  'Multi_off (32).png',
#  'Multi_off (33).png',
#  'Multi_off (34).png',
#  'Multi_off (35).png',
#  'Multi_off (36).png',
#  'Multi_off (37).png',
#  'Multi_off (38).png',
#  'Multi_off (39).png',
#  'Multi_off (4).png',
#  'Multi_off (40).png',
#  'Multi_off (41).png',
#  'Multi_off (42).png',
#  'Multi_off (43).png',
#  'Multi_off (44).png',
#  'Multi_off (45).png',
#  'Multi_off (46).png',
#  'Multi_off (47).png',
#  'Multi_off (48).png',
#  'Multi_off (49).png',
#  'Multi_off (5).png',
#  'Multi_off (50).png',
#  'Multi_off (51).png',
#  'Multi_off (52).png',
#  'Multi_off (53).png',
#  'Multi_off (54).png',
#  'Multi_off (55).png',
#  'Multi_off (56).png',
#  'Multi_off (57).png',
#  'Multi_off (58).png',
#  'Multi_off (59).png',
#  'Multi_off (6).png',
#  'Multi_off (60).png',
#  'Multi_off (61).png',
#  'Multi_off (62).png',
#  'Multi_off (63).png',
#  'Multi_off (64).png',
#  'Multi_off (65).png',
#  'Multi_off (66).png',
#  'Multi_off (67).png',
#  'Multi_off (68).png',
#  'Multi_off (69).png',
#  'Multi_off (7).png',
#  'Multi_off (70).png',
#  'Multi_off (71).png',
#  'Multi_off (72).png',
#  'Multi_off (73).png',
#  'Multi_off (74).png',
#  'Multi_off (75).png',
#  'Multi_off (76).png',
#  'Multi_off (77).png',
#  'Multi_off (78).png',
#  'Multi_off (79).png',
#  'Multi_off (8).png',
#  'Multi_off (80).png',
#  'Multi_off (81).png',
#  'Multi_off (82).png',
#  'Multi_off (83).png',
#  'Multi_off (84).png',
#  'Multi_off (85).png',
#  'Multi_off (86).png',
#  'Multi_off (87).png',
#  'Multi_off (88).png',
#  'Multi_off (89).png',
#  'Multi_off (9).png',
#  'Multi_off (90).png',
#  'Multi_off (91).png',
#  'Multi_off (92).png',
#  'Multi_off (93).png',
#  'Multi_off (94).png',
#  'Multi_off (95).png',
#  'Multi_off (96).png',
#  'Multi_off (97).png',
#  'Multi_off (98).png',
#  'Multi_off (99).png',
#  'Multi_re (1).png',
#  'Multi_re (10).png',
#  'Multi_re (11).png',
#  'Multi_re (12).png',
#  'Multi_re (13).png',
#  'Multi_re (14).png',
#  'Multi_re (15).png',
#  'Multi_re (16).png',
#  'Multi_re (17).png',
#  'Multi_re (18).png',
#  'Multi_re (19).png',
#  'Multi_re (2).png',
#  'Multi_re (20).png',
#  'Multi_re (21).png',
#  'Multi_re (22).png',
#  'Multi_re (23).png',
#  'Multi_re (24).png',
#  'Multi_re (25).png',
#  'Multi_re (26).png',
#  'Multi_re (27).png',
#  'Multi_re (28).png',
#  'Multi_re (29).png',
#  'Multi_re (3).png',
#  'Multi_re (30).png',
#  'Multi_re (31).png',
#  'Multi_re (32).png',
#  'Multi_re (33).png',
#  'Multi_re (34).png',
#  'Multi_re (35).png',
#  'Multi_re (36).png',
#  'Multi_re (37).png',
#  'Multi_re (38).png',
#  'Multi_re (39).png',
#  'Multi_re (4).png',
#  'Multi_re (40).png',
#  'Multi_re (41).png',
#  'Multi_re (42).png',
#  'Multi_re (43).png',
#  'Multi_re (44).png',
#  'Multi_re (45).png',
#  'Multi_re (46).png',
#  'Multi_re (47).png',
#  'Multi_re (48).png',
#  'Multi_re (49).png',
#  'Multi_re (5).png',
#  'Multi_re (50).png',
#  'Multi_re (51).png',
#  'Multi_re (52).png',
#  'Multi_re (53).png',
#  'Multi_re (54).png',
#  'Multi_re (55).png',
#  'Multi_re (56).png',
#  'Multi_re (57).png',
#  'Multi_re (58).png',
#  'Multi_re (59).png',
#  'Multi_re (6).png',
#  'Multi_re (60).png',
#  'Multi_re (61).png',
#  'Multi_re (62).png',
#  'Multi_re (63).png',
#  'Multi_re (64).png',
#  'Multi_re (65).png',
#  'Multi_re (66).png',
#  'Multi_re (67).png',
#  'Multi_re (68).png',
#  'Multi_re (69).png',
#  'Multi_re (7).png',
#  'Multi_re (70).png',
#  'Multi_re (71).png',
#  'Multi_re (72).png',
#  'Multi_re (73).png',
#  'Multi_re (74).png',
#  'Multi_re (75).png',
#  'Multi_re (76).png',
#  'Multi_re (77).png',
#  'Multi_re (78).png',
#  'Multi_re (79).png',
#  'Multi_re (8).png',
#  'Multi_re (80).png',
#  'Multi_re (81).png',
#  'Multi_re (82).png',
#  'Multi_re (83).png',
#  'Multi_re (84).png',
#  'Multi_re (85).png',
#  'Multi_re (86).png',
#  'Multi_re (87).png',
#  'Multi_re (88).png',
#  'Multi_re (89).png',
#  'Multi_re (9).png',
#  'Multi_re (90).png',
#  'RMFD-1_off (1).png',
#  'RMFD-1_off (10).png',
#  'RMFD-1_off (100).png',
#  'RMFD-1_off (1000).png',
#  'RMFD-1_off (10000).png',
#  'RMFD-1_off (10001).png',
#  'RMFD-1_off (10002).png',
#  'RMFD-1_off (10003).png',
#  'RMFD-1_off (10004).png',
#  'RMFD-1_off (10005).png',
#  'RMFD-1_off (10006).png',
#  'RMFD-1_off (10007).png',
#  'RMFD-1_off (10008).png',
#  'RMFD-1_off (10009).png',
#  'RMFD-1_off (1001).png',
#  'RMFD-1_off (10010).png',
#  'RMFD-1_off (10011).png',
#  'RMFD-1_off (10012).png',
#  'RMFD-1_off (10013).png',
#  'RMFD-1_off (10014).png',
#  'RMFD-1_off (10015).png',
#  'RMFD-1_off (10016).png',
#  'RMFD-1_off (10017).png',
#  'RMFD-1_off (10018).png',
#  'RMFD-1_off (10019).png',
#  'RMFD-1_off (1002).png',
#  'RMFD-1_off (10020).png',
#  'RMFD-1_off (10021).png',
#  'RMFD-1_off (10022).png',
#  'RMFD-1_off (10023).png',
#  'RMFD-1_off (10024).png',
#  'RMFD-1_off (10025).png',
#  'RMFD-1_off (10026).png',
#  'RMFD-1_off (10027).png',
#  'RMFD-1_off (10028).png',
#  'RMFD-1_off (10029).png',
#  'RMFD-1_off (1003).png',
#  'RMFD-1_off (10030).png',
#  'RMFD-1_off (10031).png',
#  'RMFD-1_off (10032).png',
#  'RMFD-1_off (10033).png',
#  'RMFD-1_off (10034).png',
#  'RMFD-1_off (10035).png',
#  'RMFD-1_off (10036).png',
#  'RMFD-1_off (10037).png',
#  'RMFD-1_off (10038).png',
#  'RMFD-1_off (10039).png',
#  'RMFD-1_off (1004).png',
#  'RMFD-1_off (10040).png',
#  'RMFD-1_off (10041).png',
#  'RMFD-1_off (10042).png',
#  'RMFD-1_off (10043).png',
#  'RMFD-1_off (10044).png',
#  'RMFD-1_off (10045).png',
#  'RMFD-1_off (10046).png',
#  'RMFD-1_off (10047).png',
#  'RMFD-1_off (10048).png',
#  'RMFD-1_off (10049).png',
#  'RMFD-1_off (1005).png',
#  'RMFD-1_off (10050).png',
#  'RMFD-1_off (10051).png',
#  'RMFD-1_off (10052).png',
#  'RMFD-1_off (10053).png',
#  'RMFD-1_off (10054).png',
#  'RMFD-1_off (10055).png',
#  'RMFD-1_off (10056).png',
#  'RMFD-1_off (10057).png',
#  'RMFD-1_off (10058).png',
#  'RMFD-1_off (10059).png',
#  'RMFD-1_off (1006).png',
#  'RMFD-1_off (10060).png',
#  'RMFD-1_off (10061).png',
#  'RMFD-1_off (10062).png',
#  'RMFD-1_off (10063).png',
#  'RMFD-1_off (10064).png',
#  'RMFD-1_off (10065).png',
#  'RMFD-1_off (10066).png',
#  'RMFD-1_off (10067).png',
#  'RMFD-1_off (10068).png',
#  'RMFD-1_off (10069).png',
#  'RMFD-1_off (1007).png',
#  'RMFD-1_off (10070).png',
#  'RMFD-1_off (10071).png',
#  'RMFD-1_off (10072).png',
#  'RMFD-1_off (10073).png',
#  'RMFD-1_off (10074).png',
#  'RMFD-1_off (10075).png',
#  'RMFD-1_off (10076).png',
#  'RMFD-1_off (10077).png',
#  'RMFD-1_off (10078).png',
#  'RMFD-1_off (10079).png',
#  'RMFD-1_off (1008).png',
#  'RMFD-1_off (10080).png',
#  'RMFD-1_off (10081).png',
#  'RMFD-1_off (10082).png',
#  'RMFD-1_off (10083).png',
#  'RMFD-1_off (10084).png',
#  'RMFD-1_off (10085).png',
#  'RMFD-1_off (10086).png',
#  'RMFD-1_off (10087).png',
#  'RMFD-1_off (10088).png',
#  'RMFD-1_off (10089).png',
#  'RMFD-1_off (1009).png',
#  'RMFD-1_off (10090).png',
#  'RMFD-1_off (10091).png',
#  'RMFD-1_off (10092).png',
#  'RMFD-1_off (10093).png',
#  'RMFD-1_off (10094).png',
#  'RMFD-1_off (10095).png',
#  'RMFD-1_off (10096).png',
#  'RMFD-1_off (10097).png',
#  'RMFD-1_off (10098).png',
#  'RMFD-1_off (10099).png',
#  'RMFD-1_off (101).png',
#  'RMFD-1_off (1010).png',
#  'RMFD-1_off (10100).png',
#  'RMFD-1_off (10101).png',
#  'RMFD-1_off (10102).png',
#  'RMFD-1_off (10103).png',
#  'RMFD-1_off (10104).png',
#  'RMFD-1_off (10105).png',
#  'RMFD-1_off (10106).png',
#  'RMFD-1_off (10107).png',
#  'RMFD-1_off (10108).png',
#  'RMFD-1_off (10109).png',
#  'RMFD-1_off (1011).png',
#  'RMFD-1_off (10110).png',
#  'RMFD-1_off (10111).png',
#  'RMFD-1_off (10112).png',
#  'RMFD-1_off (10113).png',
#  'RMFD-1_off (10114).png',
#  'RMFD-1_off (10115).png',
#  'RMFD-1_off (10116).png',
#  'RMFD-1_off (10117).png',
#  'RMFD-1_off (10118).png',
#  'RMFD-1_off (10119).png',
#  'RMFD-1_off (1012).png',
#  'RMFD-1_off (10120).png',
#  'RMFD-1_off (10121).png',
#  'RMFD-1_off (10122).png',
#  'RMFD-1_off (10123).png',
#  'RMFD-1_off (10124).png',
#  'RMFD-1_off (10125).png',
#  'RMFD-1_off (10126).png',
#  'RMFD-1_off (10127).png',
#  'RMFD-1_off (10128).png',
#  'RMFD-1_off (10129).png',
#  'RMFD-1_off (1013).png',
#  'RMFD-1_off (10130).png',
#  'RMFD-1_off (10131).png',
#  'RMFD-1_off (10132).png',
#  'RMFD-1_off (10133).png',
#  'RMFD-1_off (10134).png',
#  'RMFD-1_off (10135).png',
#  'RMFD-1_off (10136).png',
#  'RMFD-1_off (10137).png',
#  'RMFD-1_off (10138).png',
#  'RMFD-1_off (10139).png',
#  'RMFD-1_off (1014).png',
#  'RMFD-1_off (10140).png',
#  'RMFD-1_off (10141).png',
#  'RMFD-1_off (10142).png',
#  'RMFD-1_off (10143).png',
#  'RMFD-1_off (10144).png',
#  'RMFD-1_off (10145).png',
#  'RMFD-1_off (10146).png',
#  'RMFD-1_off (10147).png',
#  'RMFD-1_off (10148).png',
#  'RMFD-1_off (10149).png',
#  'RMFD-1_off (1015).png',
#  'RMFD-1_off (10150).png',
#  'RMFD-1_off (10151).png',
#  'RMFD-1_off (10152).png',
#  'RMFD-1_off (10153).png',
#  'RMFD-1_off (10154).png',
#  'RMFD-1_off (10155).png',
#  'RMFD-1_off (10156).png',
#  'RMFD-1_off (10157).png',
#  'RMFD-1_off (10158).png',
#  'RMFD-1_off (10159).png',
#  'RMFD-1_off (1016).png',
#  'RMFD-1_off (10160).png',
#  'RMFD-1_off (10161).png',
#  'RMFD-1_off (10162).png',
#  'RMFD-1_off (10163).png',
#  'RMFD-1_off (10164).png',
#  'RMFD-1_off (10165).png',
#  'RMFD-1_off (10166).png',
#  'RMFD-1_off (10167).png',
#  'RMFD-1_off (10168).png',
#  'RMFD-1_off (10169).png',
#  'RMFD-1_off (1017).png',
#  'RMFD-1_off (10170).png',
#  'RMFD-1_off (10171).png',
#  'RMFD-1_off (10172).png',
#  'RMFD-1_off (10173).png',
#  'RMFD-1_off (10174).png',
#  'RMFD-1_off (10175).png',
#  'RMFD-1_off (10176).png',
#  'RMFD-1_off (10177).png',
#  'RMFD-1_off (10178).png',
#  'RMFD-1_off (10179).png',
#  'RMFD-1_off (1018).png',
#  'RMFD-1_off (10180).png',
#  'RMFD-1_off (10181).png',
#  'RMFD-1_off (10182).png',
#  'RMFD-1_off (10183).png',
#  'RMFD-1_off (10184).png',
#  'RMFD-1_off (10185).png',
#  'RMFD-1_off (10186).png',
#  'RMFD-1_off (10187).png',
#  'RMFD-1_off (10188).png',
#  'RMFD-1_off (10189).png',
#  'RMFD-1_off (1019).png',
#  'RMFD-1_off (10190).png',
#  'RMFD-1_off (10191).png',
#  'RMFD-1_off (10192).png',
#  'RMFD-1_off (10193).png',
#  'RMFD-1_off (10194).png',
#  'RMFD-1_off (10195).png',
#  'RMFD-1_off (10196).png',
#  'RMFD-1_off (10197).png',
#  'RMFD-1_off (10198).png',
#  'RMFD-1_off (10199).png',
#  'RMFD-1_off (102).png',
#  'RMFD-1_off (1020).png',
#  'RMFD-1_off (10200).png',
#  'RMFD-1_off (10201).png',
#  'RMFD-1_off (10202).png',
#  'RMFD-1_off (10203).png',
#  'RMFD-1_off (10204).png',
#  'RMFD-1_off (10205).png',
#  'RMFD-1_off (10206).png',
#  'RMFD-1_off (10207).png',
#  'RMFD-1_off (10208).png',
#  'RMFD-1_off (10209).png',
#  'RMFD-1_off (1021).png',
#  'RMFD-1_off (10210).png',
#  'RMFD-1_off (10211).png',
#  'RMFD-1_off (10212).png',
#  'RMFD-1_off (10213).png',
#  'RMFD-1_off (10214).png',
#  'RMFD-1_off (10215).png',
#  'RMFD-1_off (10216).png',
#  'RMFD-1_off (10217).png',
#  'RMFD-1_off (10218).png',
#  'RMFD-1_off (10219).png',
#  'RMFD-1_off (1022).png',
#  'RMFD-1_off (10220).png',
#  'RMFD-1_off (10221).png',
#  'RMFD-1_off (10222).png',
#  'RMFD-1_off (10223).png',
#  'RMFD-1_off (10224).png',
#  'RMFD-1_off (10225).png',
#  'RMFD-1_off (10226).png',
#  'RMFD-1_off (10227).png',
#  'RMFD-1_off (10228).png',
#  'RMFD-1_off (10229).png',
#  'RMFD-1_off (1023).png',
#  'RMFD-1_off (10230).png',
#  'RMFD-1_off (10231).png',
#  'RMFD-1_off (10232).png',
#  'RMFD-1_off (10233).png',
#  'RMFD-1_off (10234).png',
#  'RMFD-1_off (10235).png',
#  'RMFD-1_off (10236).png',
#  'RMFD-1_off (10237).png',
#  'RMFD-1_off (10238).png',
#  'RMFD-1_off (10239).png',
#  'RMFD-1_off (1024).png',
#  'RMFD-1_off (10240).png',
#  'RMFD-1_off (10241).png',
#  'RMFD-1_off (10242).png',
#  'RMFD-1_off (10243).png',
#  'RMFD-1_off (10244).png',
#  'RMFD-1_off (10245).png',
#  'RMFD-1_off (10246).png',
#  'RMFD-1_off (10247).png',
#  'RMFD-1_off (10248).png',
#  'RMFD-1_off (10249).png',
#  'RMFD-1_off (1025).png',
#  'RMFD-1_off (10250).png',
#  'RMFD-1_off (10251).png',
#  'RMFD-1_off (10252).png',
#  'RMFD-1_off (10253).png',
#  'RMFD-1_off (10254).png',
#  'RMFD-1_off (10255).png',
#  'RMFD-1_off (10256).png',
#  'RMFD-1_off (10257).png',
#  'RMFD-1_off (10258).png',
#  'RMFD-1_off (10259).png',
#  'RMFD-1_off (1026).png',
#  'RMFD-1_off (10260).png',
#  'RMFD-1_off (10261).png',
#  'RMFD-1_off (10262).png',
#  'RMFD-1_off (10263).png',
#  'RMFD-1_off (10264).png',
#  'RMFD-1_off (10265).png',
#  'RMFD-1_off (10266).png',
#  'RMFD-1_off (10267).png',
#  'RMFD-1_off (10268).png',
#  'RMFD-1_off (10269).png',
#  'RMFD-1_off (1027).png',
#  'RMFD-1_off (10270).png',
#  'RMFD-1_off (10271).png',
#  'RMFD-1_off (10272).png',
#  'RMFD-1_off (10273).png',
#  'RMFD-1_off (10274).png',
#  'RMFD-1_off (10275).png',
#  'RMFD-1_off (10276).png',
#  'RMFD-1_off (10277).png',
#  'RMFD-1_off (10278).png',
#  'RMFD-1_off (10279).png',
#  'RMFD-1_off (1028).png',
#  'RMFD-1_off (10280).png',
#  'RMFD-1_off (10281).png',
#  'RMFD-1_off (10282).png',
#  'RMFD-1_off (10283).png',
#  'RMFD-1_off (10284).png',
#  'RMFD-1_off (10285).png',
#  'RMFD-1_off (10286).png',
#  'RMFD-1_off (10287).png',
#  'RMFD-1_off (10288).png',
#  'RMFD-1_off (10289).png',
#  'RMFD-1_off (1029).png',
#  'RMFD-1_off (10290).png',
#  'RMFD-1_off (10291).png',
#  'RMFD-1_off (10292).png',
#  'RMFD-1_off (10293).png',
#  'RMFD-1_off (10294).png',
#  'RMFD-1_off (10295).png',
#  'RMFD-1_off (10296).png',
#  'RMFD-1_off (10297).png',
#  'RMFD-1_off (10298).png',
#  'RMFD-1_off (10299).png',
#  'RMFD-1_off (103).png',
#  'RMFD-1_off (1030).png',
#  'RMFD-1_off (10300).png',
#  'RMFD-1_off (10301).png',
#  'RMFD-1_off (10302).png',
#  'RMFD-1_off (10303).png',
#  'RMFD-1_off (10304).png',
#  'RMFD-1_off (10305).png',
#  'RMFD-1_off (10306).png',
#  'RMFD-1_off (10307).png',
#  'RMFD-1_off (10308).png',
#  'RMFD-1_off (10309).png',
#  'RMFD-1_off (1031).png',
#  'RMFD-1_off (10310).png',
#  'RMFD-1_off (10311).png',
#  'RMFD-1_off (10312).png',
#  'RMFD-1_off (10313).png',
#  'RMFD-1_off (10314).png',
#  'RMFD-1_off (10315).png',
#  'RMFD-1_off (10316).png',
#  'RMFD-1_off (10317).png',
#  'RMFD-1_off (10318).png',
#  'RMFD-1_off (10319).png',
#  'RMFD-1_off (1032).png',
#  'RMFD-1_off (10320).png',
#  'RMFD-1_off (10321).png',
#  'RMFD-1_off (10322).png',
#  'RMFD-1_off (10323).png',
#  'RMFD-1_off (10324).png',
#  'RMFD-1_off (10325).png',
#  'RMFD-1_off (10326).png',
#  'RMFD-1_off (10327).png',
#  'RMFD-1_off (10328).png',
#  'RMFD-1_off (10329).png',
#  'RMFD-1_off (1033).png',
#  'RMFD-1_off (10330).png',
#  'RMFD-1_off (10331).png',
#  'RMFD-1_off (10332).png',
#  'RMFD-1_off (10333).png',
#  'RMFD-1_off (10334).png',
#  'RMFD-1_off (10335).png',
#  'RMFD-1_off (10336).png',
#  'RMFD-1_off (10337).png',
#  'RMFD-1_off (10338).png',
#  'RMFD-1_off (10339).png',
#  'RMFD-1_off (1034).png',
#  'RMFD-1_off (10340).png',
#  'RMFD-1_off (10341).png',
#  'RMFD-1_off (10342).png',
#  'RMFD-1_off (10343).png',
#  'RMFD-1_off (10344).png',
#  'RMFD-1_off (10345).png',
#  'RMFD-1_off (10346).png',
#  'RMFD-1_off (10347).png',
#  'RMFD-1_off (10348).png',
#  'RMFD-1_off (10349).png',
#  'RMFD-1_off (1035).png',
#  'RMFD-1_off (10350).png',
#  'RMFD-1_off (10351).png',
#  'RMFD-1_off (10352).png',
#  'RMFD-1_off (10353).png',
#  'RMFD-1_off (10354).png',
#  'RMFD-1_off (10355).png',
#  'RMFD-1_off (10356).png',
#  ...]

# %%
categories=[]
for filename in filenames:
    
    category = filename.split(" ")[0]
    
    if (category == "RMFD-1_on") or (category == "Capture_on"):
        categories.append(1)
        
    elif (category == "RMFD-1_off") or (category == "Capture_off") or (category == "Multi_off"):
        categories.append(0)
        
    elif category == "Multi_re":
        categories.append(2)
        
    else:
        categories.append(3)
        
data_df = pd.DataFrame({'FileName':filenames, 'Category':categories})

# 이미지 제너레이터에서 class_mode='categorical'로 지정하기 위해 컬럼을 string으로 변경함
data_df['Category'] = data_df['Category'].replace({0:"mask_off", 1:"mask_on", 2:"mask_re", 3:"no_face"})
data_df
# Out:
#                   FileName Category
# 0       Background (1).png  no_face
# 1      Background (10).png  no_face
# 2      Background (11).png  no_face
# 3      Background (12).png  no_face
# 4      Background (13).png  no_face
# 5      Background (14).png  no_face
# 6      Background (15).png  no_face
# 7      Background (16).png  no_face
# 8      Background (17).png  no_face
# 9      Background (18).png  no_face
# 10     Background (19).png  no_face
# 11      Background (2).png  no_face
# 12     Background (20).png  no_face
# 13     Background (21).png  no_face
# 14     Background (22).png  no_face
# 15     Background (23).png  no_face
# 16     Background (24).png  no_face
# 17     Background (25).png  no_face
# 18     Background (26).png  no_face
# 19     Background (27).png  no_face
# 20     Background (28).png  no_face
# 21     Background (29).png  no_face
# 22      Background (3).png  no_face
# 23     Background (30).png  no_face
# 24     Background (31).png  no_face
# 25     Background (32).png  no_face
# 26     Background (33).png  no_face
# 27     Background (34).png  no_face
# 28     Background (35).png  no_face
# 29      Background (4).png  no_face
# ...                    ...      ...
# 13303  RMFD-1_on (972).png  mask_on
# 13304  RMFD-1_on (973).png  mask_on
# 13305  RMFD-1_on (974).png  mask_on
# 13306  RMFD-1_on (975).png  mask_on
# 13307  RMFD-1_on (976).png  mask_on
# 13308  RMFD-1_on (977).png  mask_on
# 13309  RMFD-1_on (978).png  mask_on
# 13310  RMFD-1_on (979).png  mask_on
# 13311   RMFD-1_on (98).png  mask_on
# 13312  RMFD-1_on (980).png  mask_on
# 13313  RMFD-1_on (981).png  mask_on
# 13314  RMFD-1_on (982).png  mask_on
# 13315  RMFD-1_on (983).png  mask_on
# 13316  RMFD-1_on (984).png  mask_on
# 13317  RMFD-1_on (985).png  mask_on
# 13318  RMFD-1_on (986).png  mask_on
# 13319  RMFD-1_on (987).png  mask_on
# 13320  RMFD-1_on (988).png  mask_on
# 13321  RMFD-1_on (989).png  mask_on
# 13322   RMFD-1_on (99).png  mask_on
# 13323  RMFD-1_on (990).png  mask_on
# 13324  RMFD-1_on (991).png  mask_on
# 13325  RMFD-1_on (992).png  mask_on
# 13326  RMFD-1_on (993).png  mask_on
# 13327  RMFD-1_on (994).png  mask_on
# 13328  RMFD-1_on (995).png  mask_on
# 13329  RMFD-1_on (996).png  mask_on
# 13330  RMFD-1_on (997).png  mask_on
# 13331  RMFD-1_on (998).png  mask_on
# 13332  RMFD-1_on (999).png  mask_on
#
# [13333 rows x 2 columns]

# %%
train_df, validation_df = train_test_split(data_df, test_size=0.2, stratify=data_df['Category'], random_state=42) 

train_df = train_df.reset_index(drop=True)
validation_df = validation_df.reset_index(drop=True)

# %% [markdown]
# # 4. Modeling

# %%
from keras.applications import VGG19
from keras.models import Model
from keras.layers import *

IMAGE_WIDTH = 224
IMAGE_HEIGHT = 224
IMAGE_SIZE = (IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNEL = 3

model_name = "MaskCheckModel_Ver1.3.h5"

# %%
# [참고] https://handcoding.tistory.com/195

input = Input(shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3))
model = VGG19(input_tensor=input,include_top=False, weights=None)

x = model.output
x = Flatten()(x)
x = Dense(1024, name='fully', init='uniform')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dense(512, init='uniform')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dense(4, activation='softmax', name='softmax')(x)

model = Model(model.input, x)

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# fully (Dense)                (None, 1024)              25691136
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 1024)              4096
# _________________________________________________________________
# activation_7 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               524800
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_8 (Activation)    (None, 512)               0
# _________________________________________________________________
# softmax (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 46,248,516
# Trainable params: 46,245,444
# Non-trainable params: 3,072
# _________________________________________________________________
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1024, name="fully", kernel_initializer="uniform")`
#
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(512, kernel_initializer="uniform")`
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# # 5. Training

# %%
batch_size = 16

# %%
# [참고] https://3months.tistory.com/199

train_datagen = ImageDataGenerator(
    rotation_range = 20,
    width_shift_range = 0.2,
    height_shift_range = 0.2,
    zoom_range = 0.3,
    rescale=1./255
)

train_generator = train_datagen.flow_from_dataframe( # flow_from_directory
    train_df,
    dir_data,
    x_col = 'FileName',
    y_col = 'Category',
    target_size = IMAGE_SIZE,
    class_mode = "categorical",
    batch_size = batch_size
)
# Out:
# Found 10666 validated image filenames belonging to 4 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)

validation_generator = validation_datagen.flow_from_dataframe(
    validation_df,
    dir_data,
    x_col = 'FileName',
    y_col = 'Category',
    target_size = IMAGE_SIZE,
    class_mode = "categorical",
    batch_size = batch_size
)
# Out:
# Found 2667 validated image filenames belonging to 4 classes.

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

earlystop = EarlyStopping(monitor='val_loss', min_delta=0.01, mode='min', patience=10)

# [참고] https://teddylee777.github.io/tensorflow/keras-%EC%BD%9C%EB%B0%B1%ED%95%A8%EC%88%98-vol-01
# ReduceLROnPlateau : loss가 더이상 개선되지 않으면 lr을 감소시킴
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5, min_lr=0.00001, verbose=1)
# factor: factor by which the learning rate will be reduced. new_lr = lr * factor

# [참고] https://blog.naver.com/PostView.nhn?blogId=cjh226&logNo=221468928164&redirect=Dlog&widgetTypeCall=true&directAccess=false
checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True)

callbacks=[earlystop, learning_rate_reduction, checkpoint]

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
total_train = train_df.shape[0]
total_validation = validation_df.shape[0]

history = model.fit_generator(
    train_generator,
    epochs = 100,
    steps_per_epoch = total_train // batch_size,
    validation_data = validation_generator,
    validation_steps = total_validation // batch_size,
    callbacks = callbacks
)
# Out:
# Epoch 1/100
# 666/666 [==============================] - 250s 375ms/step - loss: 0.4436 - acc: 0.8387 - val_loss: 6.8163 - val_acc: 0.1691
# Epoch 2/100
# 666/666 [==============================] - 244s 366ms/step - loss: 0.3510 - acc: 0.8711 - val_loss: 0.4969 - val_acc: 0.8876
# Epoch 3/100
# 666/666 [==============================] - 244s 366ms/step - loss: 0.2897 - acc: 0.8994 - val_loss: 0.1807 - val_acc: 0.9472
# Epoch 4/100
# 666/666 [==============================] - 244s 366ms/step - loss: 0.2523 - acc: 0.9121 - val_loss: 0.2668 - val_acc: 0.9147
# Epoch 5/100
# 666/666 [==============================] - 244s 366ms/step - loss: 0.2271 - acc: 0.9229 - val_loss: 0.1962 - val_acc: 0.9287
# Epoch 6/100
# 666/666 [==============================] - 244s 366ms/step - loss: 0.2200 - acc: 0.9266 - val_loss: 0.1378 - val_acc: 0.9611
# Epoch 7/100
# 666/666 [==============================] - 244s 366ms/step - loss: 0.1777 - acc: 0.9459 - val_loss: 0.1964 - val_acc: 0.9578
# Epoch 8/100
# 666/666 [==============================] - 244s 366ms/step - loss: 0.1719 - acc: 0.9484 - val_loss: 0.1365 - val_acc: 0.9619
# Epoch 9/100
# 666/666 [==============================] - 244s 366ms/step - loss: 0.1695 - acc: 0.9485 - val_loss: 0.1395 - val_acc: 0.9634
# Epoch 10/100
# 666/666 [==============================] - 244s 366ms/step - loss: 0.1547 - acc: 0.9538 - val_loss: 0.1484 - val_acc: 0.9687
# Epoch 11/100
# 666/666 [==============================] - 244s 366ms/step - loss: 0.1550 - acc: 0.9531 - val_loss: 0.1017 - val_acc: 0.9725
# Epoch 12/100
# 666/666 [==============================] - 244s 366ms/step - loss: 0.1460 - acc: 0.9544 - val_loss: 0.0819 - val_acc: 0.9751
# Epoch 13/100
# 666/666 [==============================] - 244s 366ms/step - loss: 0.1409 - acc: 0.9570 - val_loss: 0.0989 - val_acc: 0.9694
# Epoch 14/100
# 666/666 [==============================] - 244s 366ms/step - loss: 0.1364 - acc: 0.9558 - val_loss: 0.1367 - val_acc: 0.9683
# Epoch 15/100
# 666/666 [==============================] - 244s 366ms/step - loss: 0.1351 - acc: 0.9583 - val_loss: 0.1040 - val_acc: 0.9721
# Epoch 16/100
# 666/666 [==============================] - 243s 365ms/step - loss: 0.1366 - acc: 0.9558 - val_loss: 0.1349 - val_acc: 0.9679
# Epoch 17/100
# 666/666 [==============================] - 243s 366ms/step - loss: 0.1268 - acc: 0.9588 - val_loss: 0.2146 - val_acc: 0.9363
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 18/100
# 666/666 [==============================] - 244s 366ms/step - loss: 0.1139 - acc: 0.9642 - val_loss: 0.0817 - val_acc: 0.9725
# Epoch 19/100
# 666/666 [==============================] - 244s 366ms/step - loss: 0.1084 - acc: 0.9655 - val_loss: 0.0789 - val_acc: 0.9755
# Epoch 20/100
# 666/666 [==============================] - 244s 366ms/step - loss: 0.1045 - acc: 0.9673 - val_loss: 0.1512 - val_acc: 0.9544
# Epoch 21/100
# 666/666 [==============================] - 243s 366ms/step - loss: 0.1024 - acc: 0.9681 - val_loss: 0.0721 - val_acc: 0.9770
# Epoch 22/100
# 666/666 [==============================] - 243s 366ms/step - loss: 0.1061 - acc: 0.9642 - val_loss: 0.0800 - val_acc: 0.9759

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

xLen = np.arange(len(loss))
plt.plot(xLen, loss, marker=".", c='red', label="train_loss")
plt.plot(xLen, val_loss, marker=".", c='blue', label="val_loss")
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # 6. Model Save

# %%
# from keras.models import load_model

# model.save(model_name)
